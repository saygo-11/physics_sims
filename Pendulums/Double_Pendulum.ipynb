# %% [markdown]
# # A Double Pendulum Simulator
# ### *An exercise in using Matplotlib animations and more advanced numerical simulations.*
#
# Double pendulums are one of the simplest examples of chaos theory and behave according to rules that are relatively easy to encode!
#
# Key Equations include:
#
# $ a = - \frac{g}{L}\sin(\theta)dt$ for small values of $\theta$

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

# %%
g = -9.8 #gravitational acceleration (m/s^2)
dt = 0.1 #time step
t_max = 20 #end time

class Pendulum():
    def __init__(self, length, mass, init_theta):
        self.l = length
        self.m = mass
        self.theta = init_theta
        self.v = 0
        self.x = 0
        self.y = 0

    #@classmethod

# %%
ax.set(xlim=(-10,10), ylim=(-10,3))

# %%
ani = animation.FuncAnimation(fig=fig, func=update, frames=30, interval=30)
